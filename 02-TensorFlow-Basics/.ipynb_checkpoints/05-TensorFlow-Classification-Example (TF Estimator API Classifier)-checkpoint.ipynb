# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd
# tf.logging.set_verbosity(tf.logging.FATAL)

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
# normalize data
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes[cols_to_norm].describe().T
# Out:
#                        count      mean       std  min       25%       50%  \
# Number_pregnant        768.0  0.226180  0.198210  0.0  0.058824  0.176471
# Glucose_concentration  768.0  0.607510  0.160666  0.0  0.497487  0.587940
# Blood_pressure         768.0  0.566438  0.158654  0.0  0.508197  0.590164
# Triceps                768.0  0.207439  0.161134  0.0  0.000000  0.232323
# Insulin                768.0  0.094326  0.136222  0.0  0.000000  0.036052
# BMI                    768.0  0.476790  0.117499  0.0  0.406855  0.476900
# Pedigree               768.0  0.168179  0.141473  0.0  0.070773  0.125747
#
#                             75%  max
# Number_pregnant        0.352941  1.0
# Glucose_concentration  0.704774  1.0
# Blood_pressure         0.655738  1.0
# Triceps                0.323232  1.0
# Insulin                0.150414  1.0
# BMI                    0.545455  1.0
# Pedigree               0.234095  1.0

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
num_preg
# Out:
# NumericColumn(key='Number_pregnant', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)

# %% [markdown]
# ####  **below is my way that automates**

# %%
numeric_columns = [i for i in diabetes.columns[:-2] if diabetes[i].dtype!='object']
print(numeric_columns)
# Out:
# ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps', 'Insulin', 'BMI', 'Pedigree', 'Age']

# %%
numeric_features = [tf.feature_column.numeric_column(key = column) for column in numeric_columns]

# %%
numeric_features[0]
# Out:
# NumericColumn(key='Number_pregnant', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
assigned_group
# Out:
# VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
# Alternative: hash bucket
# hash_bucket_size: maximum number of categories 
assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)
assigned_group
# Out:
# HashedCategoricalColumn(key='Group', hash_bucket_size=10, dtype=tf.string)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %%
age_buckets
# Out:
# BucketizedColumn(source_column=NumericColumn(key='Age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(20, 30, 40, 50, 60, 70, 80))

# %% [markdown]
# ### Putting them together

# %% [markdown]
# all_features

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null int64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(6), int64(3), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)

# %%
model.train(input_fn=input_func,steps=1000)

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)

# %%
results
# Out:
# {'accuracy': 0.72834647,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.79461765,
#  'auc_precision_recall': 0.6370666,
#  'average_loss': 0.5215019,
#  'label/mean': 0.34251967,
#  'loss': 5.0946727,
#  'precision': 0.61538464,
#  'prediction/mean': 0.35781884,
#  'recall': 0.55172414,
#  'global_step': 2000}

# %%
results['accuracy']
# Out:
# 0.71653545

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
# X_test.shape

# %%
list(predictions)
# Out:
# [{'logits': array([0.02716327], dtype=float32),
#   'logistic': array([0.5067904], dtype=float32),
#   'probabilities': array([0.4932096, 0.5067904], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.63884187], dtype=float32),
#   'logistic': array([0.6544916], dtype=float32),
#   'probabilities': array([0.34550837, 0.6544916 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6045825], dtype=float32),
#   'logistic': array([0.353296], dtype=float32),
#   'probabilities': array([0.646704  , 0.35329598], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8252155], dtype=float32),
#   'logistic': array([0.3046577], dtype=float32),
#   'probabilities': array([0.6953423 , 0.30465767], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.018998], dtype=float32),
#   'logistic': array([0.11722264], dtype=float32),
#   'probabilities': array([0.8827774 , 0.11722265], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2009206], dtype=float32),
#   'logistic': array([0.7686885], dtype=float32),
#   'probabilities': array([0.2313115 , 0.76868856], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.44656813], dtype=float32),
#   'logistic': array([0.609823], dtype=float32),
#   'probabilities': array([0.39017704, 0.609823  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.83246714], dtype=float32),
#   'logistic': array([0.30312365], dtype=float32),
#   'probabilities': array([0.69687635, 0.30312365], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1686724], dtype=float32),
#   'logistic': array([0.23709503], dtype=float32),
#   'probabilities': array([0.762905  , 0.23709504], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3007339], dtype=float32),
#   'logistic': array([0.21404153], dtype=float32),
#   'probabilities': array([0.78595847, 0.21404153], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1753619], dtype=float32),
#   'logistic': array([0.10198489], dtype=float32),
#   'probabilities': array([0.89801514, 0.10198493], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9536904], dtype=float32),
#   'logistic': array([0.12415147], dtype=float32),
#   'probabilities': array([0.8758485 , 0.12415151], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9089276], dtype=float32),
#   'logistic': array([0.28721935], dtype=float32),
#   'probabilities': array([0.71278065, 0.28721935], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.27396655], dtype=float32),
#   'logistic': array([0.5680664], dtype=float32),
#   'probabilities': array([0.43193355, 0.5680664 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6599938], dtype=float32),
#   'logistic': array([0.15976283], dtype=float32),
#   'probabilities': array([0.8402372 , 0.15976283], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.60244745], dtype=float32),
#   'logistic': array([0.35378397], dtype=float32),
#   'probabilities': array([0.64621603, 0.35378397], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.46255416], dtype=float32),
#   'logistic': array([0.3863801], dtype=float32),
#   'probabilities': array([0.6136199 , 0.38638008], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1205597], dtype=float32),
#   'logistic': array([0.10711449], dtype=float32),
#   'probabilities': array([0.89288545, 0.10711452], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.54874164], dtype=float32),
#   'logistic': array([0.3661564], dtype=float32),
#   'probabilities': array([0.6338436 , 0.36615643], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1272826], dtype=float32),
#   'logistic': array([0.10647324], dtype=float32),
#   'probabilities': array([0.8935268 , 0.10647324], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.387434], dtype=float32),
#   'logistic': array([0.19981769], dtype=float32),
#   'probabilities': array([0.8001823 , 0.19981772], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8364711], dtype=float32),
#   'logistic': array([0.30227855], dtype=float32),
#   'probabilities': array([0.6977214 , 0.30227852], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7502966], dtype=float32),
#   'logistic': array([0.6792433], dtype=float32),
#   'probabilities': array([0.32075667, 0.6792433 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3996377], dtype=float32),
#   'logistic': array([0.19787359], dtype=float32),
#   'probabilities': array([0.8021264 , 0.19787362], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6096553], dtype=float32),
#   'logistic': array([0.16663647], dtype=float32),
#   'probabilities': array([0.83336353, 0.16663648], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3898585], dtype=float32),
#   'logistic': array([0.80056965], dtype=float32),
#   'probabilities': array([0.19943035, 0.80056965], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6411394], dtype=float32),
#   'logistic': array([0.1623101], dtype=float32),
#   'probabilities': array([0.8376899 , 0.16231008], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.78973734], dtype=float32),
#   'logistic': array([0.3122251], dtype=float32),
#   'probabilities': array([0.68777496, 0.31222507], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.4798584], dtype=float32),
#   'logistic': array([0.0772823], dtype=float32),
#   'probabilities': array([0.92271763, 0.07728229], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.31381488], dtype=float32),
#   'logistic': array([0.5778162], dtype=float32),
#   'probabilities': array([0.42218387, 0.5778162 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([3.0404637], dtype=float32),
#   'logistic': array([0.95436907], dtype=float32),
#   'probabilities': array([0.04563098, 0.95436907], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.43327147], dtype=float32),
#   'logistic': array([0.39334542], dtype=float32),
#   'probabilities': array([0.6066546, 0.3933454], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8828908], dtype=float32),
#   'logistic': array([0.2925791], dtype=float32),
#   'probabilities': array([0.70742095, 0.29257908], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.19687581], dtype=float32),
#   'logistic': array([0.5490606], dtype=float32),
#   'probabilities': array([0.45093942, 0.5490606 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1709208], dtype=float32),
#   'logistic': array([0.23668855], dtype=float32),
#   'probabilities': array([0.76331145, 0.23668858], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6813874], dtype=float32),
#   'logistic': array([0.33595175], dtype=float32),
#   'probabilities': array([0.6640483 , 0.33595172], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.07404804], dtype=float32),
#   'logistic': array([0.51850355], dtype=float32),
#   'probabilities': array([0.48149642, 0.51850355], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.60148], dtype=float32),
#   'logistic': array([0.64599484], dtype=float32),
#   'probabilities': array([0.35400516, 0.64599484], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2157428], dtype=float32),
#   'logistic': array([0.7713135], dtype=float32),
#   'probabilities': array([0.2286865, 0.7713135], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9827883], dtype=float32),
#   'logistic': array([0.27233887], dtype=float32),
#   'probabilities': array([0.72766113, 0.27233887], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.655447], dtype=float32),
#   'logistic': array([0.16037413], dtype=float32),
#   'probabilities': array([0.8396259 , 0.16037413], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.0616715], dtype=float32),
#   'logistic': array([0.515413], dtype=float32),
#   'probabilities': array([0.484587, 0.515413], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8845758], dtype=float32),
#   'logistic': array([0.13186413], dtype=float32),
#   'probabilities': array([0.8681358 , 0.13186416], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.17191875], dtype=float32),
#   'logistic': array([0.54287416], dtype=float32),
#   'probabilities': array([0.45712587, 0.54287416], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.018937], dtype=float32),
#   'logistic': array([0.11722893], dtype=float32),
#   'probabilities': array([0.8827711 , 0.11722895], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.6119642], dtype=float32),
#   'logistic': array([0.0683724], dtype=float32),
#   'probabilities': array([0.93162763, 0.06837238], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.34828544], dtype=float32),
#   'logistic': array([0.5862017], dtype=float32),
#   'probabilities': array([0.41379824, 0.5862017 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6144063], dtype=float32),
#   'logistic': array([0.16597775], dtype=float32),
#   'probabilities': array([0.8340222 , 0.16597775], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3562101], dtype=float32),
#   'logistic': array([0.20485693], dtype=float32),
#   'probabilities': array([0.79514307, 0.20485695], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.3955524], dtype=float32),
#   'logistic': array([0.08351248], dtype=float32),
#   'probabilities': array([0.91648746, 0.08351247], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8167682], dtype=float32),
#   'logistic': array([0.13982213], dtype=float32),
#   'probabilities': array([0.8601779 , 0.13982213], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2226207], dtype=float32),
#   'logistic': array([0.22747558], dtype=float32),
#   'probabilities': array([0.7725244 , 0.22747558], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2740022], dtype=float32),
#   'logistic': array([0.21857291], dtype=float32),
#   'probabilities': array([0.7814271 , 0.21857291], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5438802], dtype=float32),
#   'logistic': array([0.36728543], dtype=float32),
#   'probabilities': array([0.6327146 , 0.36728543], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0539546], dtype=float32),
#   'logistic': array([0.11365339], dtype=float32),
#   'probabilities': array([0.88634664, 0.11365341], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4142364], dtype=float32),
#   'logistic': array([0.19556668], dtype=float32),
#   'probabilities': array([0.8044333 , 0.19556673], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5036262], dtype=float32),
#   'logistic': array([0.18188527], dtype=float32),
#   'probabilities': array([0.8181147 , 0.18188532], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4061666], dtype=float32),
#   'logistic': array([0.19683939], dtype=float32),
#   'probabilities': array([0.8031606 , 0.19683939], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.04770482], dtype=float32),
#   'logistic': array([0.48807606], dtype=float32),
#   'probabilities': array([0.51192397, 0.48807606], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9055926], dtype=float32),
#   'logistic': array([0.12947682], dtype=float32),
#   'probabilities': array([0.8705232 , 0.12947682], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3263613], dtype=float32),
#   'logistic': array([0.20976189], dtype=float32),
#   'probabilities': array([0.7902381 , 0.20976187], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.66820943], dtype=float32),
#   'logistic': array([0.66110206], dtype=float32),
#   'probabilities': array([0.33889785, 0.66110206], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6965494], dtype=float32),
#   'logistic': array([0.6674223], dtype=float32),
#   'probabilities': array([0.3325777, 0.6674223], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.03973925], dtype=float32),
#   'logistic': array([0.4900665], dtype=float32),
#   'probabilities': array([0.5099335 , 0.49006647], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.70076764], dtype=float32),
#   'logistic': array([0.33164203], dtype=float32),
#   'probabilities': array([0.66835797, 0.33164206], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02782822], dtype=float32),
#   'logistic': array([0.5069566], dtype=float32),
#   'probabilities': array([0.49304342, 0.50695664], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7083251], dtype=float32),
#   'logistic': array([0.15338105], dtype=float32),
#   'probabilities': array([0.8466189 , 0.15338108], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5395085], dtype=float32),
#   'logistic': array([0.17660674], dtype=float32),
#   'probabilities': array([0.8233933 , 0.17660674], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8419627], dtype=float32),
#   'logistic': array([0.13681933], dtype=float32),
#   'probabilities': array([0.86318064, 0.13681933], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0736477], dtype=float32),
#   'logistic': array([0.11168464], dtype=float32),
#   'probabilities': array([0.8883154 , 0.11168463], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.43597436], dtype=float32),
#   'logistic': array([0.6072994], dtype=float32),
#   'probabilities': array([0.39270064, 0.6072994 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2966926], dtype=float32),
#   'logistic': array([0.21472222], dtype=float32),
#   'probabilities': array([0.78527784, 0.21472216], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4207362], dtype=float32),
#   'logistic': array([0.3963406], dtype=float32),
#   'probabilities': array([0.6036594 , 0.39634058], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.18023086], dtype=float32),
#   'logistic': array([0.5449361], dtype=float32),
#   'probabilities': array([0.45506385, 0.5449361 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.80067986], dtype=float32),
#   'logistic': array([0.3098801], dtype=float32),
#   'probabilities': array([0.69011986, 0.30988008], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8443072], dtype=float32),
#   'logistic': array([0.6993716], dtype=float32),
#   'probabilities': array([0.3006284, 0.6993716], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2487726], dtype=float32),
#   'logistic': array([0.09545538], dtype=float32),
#   'probabilities': array([0.9045446 , 0.09545539], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5767491], dtype=float32),
#   'logistic': array([0.640319], dtype=float32),
#   'probabilities': array([0.35968095, 0.640319  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2017384], dtype=float32),
#   'logistic': array([0.09959449], dtype=float32),
#   'probabilities': array([0.9004055, 0.0995945], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.16734874], dtype=float32),
#   'logistic': array([0.5417398], dtype=float32),
#   'probabilities': array([0.45826018, 0.5417398 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6263722], dtype=float32),
#   'logistic': array([0.3483336], dtype=float32),
#   'probabilities': array([0.6516664 , 0.34833357], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8100262], dtype=float32),
#   'logistic': array([0.14063495], dtype=float32),
#   'probabilities': array([0.8593651 , 0.14063498], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.18218338], dtype=float32),
#   'logistic': array([0.5454203], dtype=float32),
#   'probabilities': array([0.4545797, 0.5454203], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.31490695], dtype=float32),
#   'logistic': array([0.57808256], dtype=float32),
#   'probabilities': array([0.42191747, 0.57808256], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.40966702], dtype=float32),
#   'logistic': array([0.60100806], dtype=float32),
#   'probabilities': array([0.39899194, 0.601008  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.742908], dtype=float32),
#   'logistic': array([0.14894393], dtype=float32),
#   'probabilities': array([0.8510561 , 0.14894395], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8426847], dtype=float32),
#   'logistic': array([0.30096966], dtype=float32),
#   'probabilities': array([0.69903034, 0.30096966], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8594034], dtype=float32),
#   'logistic': array([0.1347726], dtype=float32),
#   'probabilities': array([0.8652274 , 0.13477261], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0106199], dtype=float32),
#   'logistic': array([0.7331414], dtype=float32),
#   'probabilities': array([0.26685855, 0.7331414 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.6591496], dtype=float32),
#   'logistic': array([0.84012383], dtype=float32),
#   'probabilities': array([0.15987618, 0.84012383], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.42363656], dtype=float32),
#   'logistic': array([0.6043531], dtype=float32),
#   'probabilities': array([0.3956469 , 0.60435313], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4191796], dtype=float32),
#   'logistic': array([0.19479024], dtype=float32),
#   'probabilities': array([0.8052098 , 0.19479024], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.3131069], dtype=float32),
#   'logistic': array([0.42235658], dtype=float32),
#   'probabilities': array([0.57764345, 0.42235658], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6743878], dtype=float32),
#   'logistic': array([0.33751506], dtype=float32),
#   'probabilities': array([0.662485  , 0.33751503], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.28763783], dtype=float32),
#   'logistic': array([0.42858225], dtype=float32),
#   'probabilities': array([0.57141775, 0.42858228], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.75401497], dtype=float32),
#   'logistic': array([0.3199471], dtype=float32),
#   'probabilities': array([0.68005294, 0.3199471 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2941208], dtype=float32),
#   'logistic': array([0.42699534], dtype=float32),
#   'probabilities': array([0.57300466, 0.4269953 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8571627], dtype=float32),
#   'logistic': array([0.13503408], dtype=float32),
#   'probabilities': array([0.8649659 , 0.13503411], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2951033], dtype=float32),
#   'logistic': array([0.57324505], dtype=float32),
#   'probabilities': array([0.42675495, 0.57324505], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.34471464], dtype=float32),
#   'logistic': array([0.5853353], dtype=float32),
#   'probabilities': array([0.4146647, 0.5853353], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1893892], dtype=float32),
#   'logistic': array([0.23336819], dtype=float32),
#   'probabilities': array([0.76663184, 0.23336819], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6431781], dtype=float32),
#   'logistic': array([0.16203305], dtype=float32),
#   'probabilities': array([0.8379669 , 0.16203308], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.670012], dtype=float32),
#   'logistic': array([0.15842256], dtype=float32),
#   'probabilities': array([0.8415774 , 0.15842257], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0605695], dtype=float32),
#   'logistic': array([0.25720066], dtype=float32),
#   'probabilities': array([0.7427994 , 0.25720066], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5134281], dtype=float32),
#   'logistic': array([0.37439027], dtype=float32),
#   'probabilities': array([0.62560976, 0.37439024], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0160282], dtype=float32),
#   'logistic': array([0.11753032], dtype=float32),
#   'probabilities': array([0.8824697 , 0.11753032], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.97131836], dtype=float32),
#   'logistic': array([0.27461782], dtype=float32),
#   'probabilities': array([0.72538215, 0.2746178 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3919189], dtype=float32),
#   'logistic': array([0.19910157], dtype=float32),
#   'probabilities': array([0.8008984 , 0.19910158], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.508327], dtype=float32),
#   'logistic': array([0.07527649], dtype=float32),
#   'probabilities': array([0.9247235 , 0.07527648], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2037542], dtype=float32),
#   'logistic': array([0.09941386], dtype=float32),
#   'probabilities': array([0.9005862 , 0.09941388], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0028293], dtype=float32),
#   'logistic': array([0.7316145], dtype=float32),
#   'probabilities': array([0.2683855, 0.7316145], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6585243], dtype=float32),
#   'logistic': array([0.15996018], dtype=float32),
#   'probabilities': array([0.8400398, 0.1599602], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0926986], dtype=float32),
#   'logistic': array([0.1098085], dtype=float32),
#   'probabilities': array([0.89019144, 0.1098085 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0642583], dtype=float32),
#   'logistic': array([0.11261958], dtype=float32),
#   'probabilities': array([0.8873805 , 0.11261957], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.01030457], dtype=float32),
#   'logistic': array([0.5025761], dtype=float32),
#   'probabilities': array([0.4974239, 0.5025761], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.08395755], dtype=float32),
#   'logistic': array([0.47902292], dtype=float32),
#   'probabilities': array([0.5209771 , 0.47902295], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2696897], dtype=float32),
#   'logistic': array([0.21931037], dtype=float32),
#   'probabilities': array([0.7806896 , 0.21931037], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.38340294], dtype=float32),
#   'logistic': array([0.40530643], dtype=float32),
#   'probabilities': array([0.5946936 , 0.40530643], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6292279], dtype=float32),
#   'logistic': array([0.16393615], dtype=float32),
#   'probabilities': array([0.83606386, 0.16393617], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4000356], dtype=float32),
#   'logistic': array([0.19781046], dtype=float32),
#   'probabilities': array([0.8021895 , 0.19781046], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.03130794], dtype=float32),
#   'logistic': array([0.5078263], dtype=float32),
#   'probabilities': array([0.4921737, 0.5078264], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.14573109], dtype=float32),
#   'logistic': array([0.46363157], dtype=float32),
#   'probabilities': array([0.5363684 , 0.46363157], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9474583], dtype=float32),
#   'logistic': array([0.12483075], dtype=float32),
#   'probabilities': array([0.8751692 , 0.12483077], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.3382705], dtype=float32),
#   'logistic': array([0.41622967], dtype=float32),
#   'probabilities': array([0.58377033, 0.41622967], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.77042603], dtype=float32),
#   'logistic': array([0.68361306], dtype=float32),
#   'probabilities': array([0.31638697, 0.68361306], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.22701168], dtype=float32),
#   'logistic': array([0.55651045], dtype=float32),
#   'probabilities': array([0.44348955, 0.55651045], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.49993086], dtype=float32),
#   'logistic': array([0.37755692], dtype=float32),
#   'probabilities': array([0.6224431 , 0.37755692], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.28951585], dtype=float32),
#   'logistic': array([0.5718776], dtype=float32),
#   'probabilities': array([0.4281224, 0.5718776], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3975065], dtype=float32),
#   'logistic': array([0.1982121], dtype=float32),
#   'probabilities': array([0.8017879, 0.1982121], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.530629], dtype=float32),
#   'logistic': array([0.17790167], dtype=float32),
#   'probabilities': array([0.8220983 , 0.17790167], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.03377], dtype=float32),
#   'logistic': array([0.11570263], dtype=float32),
#   'probabilities': array([0.88429743, 0.11570264], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.96018475], dtype=float32),
#   'logistic': array([0.27684122], dtype=float32),
#   'probabilities': array([0.7231588, 0.2768412], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.12659538], dtype=float32),
#   'logistic': array([0.46839336], dtype=float32),
#   'probabilities': array([0.5316066 , 0.46839333], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8619883], dtype=float32),
#   'logistic': array([0.7030759], dtype=float32),
#   'probabilities': array([0.2969241, 0.7030759], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3708001], dtype=float32),
#   'logistic': array([0.2024906], dtype=float32),
#   'probabilities': array([0.7975094, 0.2024906], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7633073], dtype=float32),
#   'logistic': array([0.14637658], dtype=float32),
#   'probabilities': array([0.8536234 , 0.14637661], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.56849766], dtype=float32),
#   'logistic': array([0.36158356], dtype=float32),
#   'probabilities': array([0.6384164 , 0.36158353], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2663131], dtype=float32),
#   'logistic': array([0.21988907], dtype=float32),
#   'probabilities': array([0.78011096, 0.21988904], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9715722], dtype=float32),
#   'logistic': array([0.12222011], dtype=float32),
#   'probabilities': array([0.8777799 , 0.12222012], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7513783], dtype=float32),
#   'logistic': array([0.14787343], dtype=float32),
#   'probabilities': array([0.85212654, 0.14787345], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2234187], dtype=float32),
#   'logistic': array([0.09766707], dtype=float32),
#   'probabilities': array([0.9023329 , 0.09766711], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.44462997], dtype=float32),
#   'logistic': array([0.3906383], dtype=float32),
#   'probabilities': array([0.6093617, 0.3906383], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.239404], dtype=float32),
#   'logistic': array([0.77546024], dtype=float32),
#   'probabilities': array([0.22453974, 0.77546024], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2934096], dtype=float32),
#   'logistic': array([0.78472376], dtype=float32),
#   'probabilities': array([0.21527627, 0.78472376], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
# ...
#  {'logits': array([0.7609658], dtype=float32),
#   'logistic': array([0.6815634], dtype=float32),
#   'probabilities': array([0.31843662, 0.6815634 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5963148], dtype=float32),
#   'logistic': array([0.6448127], dtype=float32),
#   'probabilities': array([0.35518727, 0.6448127 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8720548], dtype=float32),
#   'logistic': array([0.7051731], dtype=float32),
#   'probabilities': array([0.29482692, 0.7051731 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.28283954], dtype=float32),
#   'logistic': array([0.42975774], dtype=float32),
#   'probabilities': array([0.5702422 , 0.42975774], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0315187], dtype=float32),
#   'logistic': array([0.26278982], dtype=float32),
#   'probabilities': array([0.7372102, 0.2627898], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.00581193], dtype=float32),
#   'logistic': array([0.501453], dtype=float32),
#   'probabilities': array([0.49854702, 0.501453  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6917], dtype=float32),
#   'logistic': array([0.15555239], dtype=float32),
#   'probabilities': array([0.84444755, 0.1555524 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.973469], dtype=float32),
#   'logistic': array([0.12201676], dtype=float32),
#   'probabilities': array([0.8779832 , 0.12201677], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6775875], dtype=float32),
#   'logistic': array([0.15741521], dtype=float32),
#   'probabilities': array([0.84258485, 0.1574152 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.03651917], dtype=float32),
#   'logistic': array([0.50912875], dtype=float32),
#   'probabilities': array([0.49087125, 0.5091288 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-3.195178], dtype=float32),
#   'logistic': array([0.03934756], dtype=float32),
#   'probabilities': array([0.9606524 , 0.03934759], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0487455], dtype=float32),
#   'logistic': array([0.2594661], dtype=float32),
#   'probabilities': array([0.7405339 , 0.25946605], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8644683], dtype=float32),
#   'logistic': array([0.13418308], dtype=float32),
#   'probabilities': array([0.8658169 , 0.13418308], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3543794], dtype=float32),
#   'logistic': array([0.20515531], dtype=float32),
#   'probabilities': array([0.7948447 , 0.20515531], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2881575], dtype=float32),
#   'logistic': array([0.21616483], dtype=float32),
#   'probabilities': array([0.7838352 , 0.21616484], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9798957], dtype=float32),
#   'logistic': array([0.2729125], dtype=float32),
#   'probabilities': array([0.7270875 , 0.27291247], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2146046], dtype=float32),
#   'logistic': array([0.7711127], dtype=float32),
#   'probabilities': array([0.22888733, 0.7711127 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6796947], dtype=float32),
#   'logistic': array([0.15713587], dtype=float32),
#   'probabilities': array([0.8428641 , 0.15713592], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1351686], dtype=float32),
#   'logistic': array([0.10572532], dtype=float32),
#   'probabilities': array([0.8942747 , 0.10572533], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.41489828], dtype=float32),
#   'logistic': array([0.6022618], dtype=float32),
#   'probabilities': array([0.3977382 , 0.60226184], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2817415], dtype=float32),
#   'logistic': array([0.4300269], dtype=float32),
#   'probabilities': array([0.5699731 , 0.43002686], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.7727637], dtype=float32),
#   'logistic': array([0.85480106], dtype=float32),
#   'probabilities': array([0.14519897, 0.85480106], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5103971], dtype=float32),
#   'logistic': array([0.62489957], dtype=float32),
#   'probabilities': array([0.37510043, 0.62489957], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1511607], dtype=float32),
#   'logistic': array([0.10422281], dtype=float32),
#   'probabilities': array([0.8957772 , 0.10422281], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5185822], dtype=float32),
#   'logistic': array([0.62681615], dtype=float32),
#   'probabilities': array([0.3731838 , 0.62681615], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.1197083], dtype=float32),
#   'logistic': array([0.5298914], dtype=float32),
#   'probabilities': array([0.47010866, 0.52989143], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.460599], dtype=float32),
#   'logistic': array([0.8116243], dtype=float32),
#   'probabilities': array([0.18837573, 0.8116242 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3518003], dtype=float32),
#   'logistic': array([0.20557621], dtype=float32),
#   'probabilities': array([0.7944238, 0.2055762], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6938877], dtype=float32),
#   'logistic': array([0.15526524], dtype=float32),
#   'probabilities': array([0.8447347 , 0.15526524], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.20089185], dtype=float32),
#   'logistic': array([0.5500547], dtype=float32),
#   'probabilities': array([0.44994527, 0.5500547 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8546753], dtype=float32),
#   'logistic': array([0.1353249], dtype=float32),
#   'probabilities': array([0.86467505, 0.1353249 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1958044], dtype=float32),
#   'logistic': array([0.76777756], dtype=float32),
#   'probabilities': array([0.23222245, 0.76777756], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.22448373], dtype=float32),
#   'logistic': array([0.55588645], dtype=float32),
#   'probabilities': array([0.44411355, 0.55588645], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6827263], dtype=float32),
#   'logistic': array([0.15673481], dtype=float32),
#   'probabilities': array([0.8432652, 0.1567348], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.1066978], dtype=float32),
#   'logistic': array([0.5266492], dtype=float32),
#   'probabilities': array([0.47335085, 0.5266492 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.19171786], dtype=float32),
#   'logistic': array([0.4522168], dtype=float32),
#   'probabilities': array([0.5477832, 0.4522168], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.4793553], dtype=float32),
#   'logistic': array([0.07731816], dtype=float32),
#   'probabilities': array([0.9226818 , 0.07731818], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.03724277], dtype=float32),
#   'logistic': array([0.49069038], dtype=float32),
#   'probabilities': array([0.5093096 , 0.49069035], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2626245], dtype=float32),
#   'logistic': array([0.56528133], dtype=float32),
#   'probabilities': array([0.43471867, 0.56528133], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2535353], dtype=float32),
#   'logistic': array([0.7779112], dtype=float32),
#   'probabilities': array([0.22208875, 0.77791125], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5071511], dtype=float32),
#   'logistic': array([0.8186386], dtype=float32),
#   'probabilities': array([0.18136138, 0.8186386 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.33769906], dtype=float32),
#   'logistic': array([0.4163685], dtype=float32),
#   'probabilities': array([0.5836315 , 0.41636854], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8359687], dtype=float32),
#   'logistic': array([0.13752876], dtype=float32),
#   'probabilities': array([0.8624712 , 0.13752876], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.5617027], dtype=float32),
#   'logistic': array([0.07164421], dtype=float32),
#   'probabilities': array([0.92835575, 0.07164421], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.383679], dtype=float32),
#   'logistic': array([0.08442575], dtype=float32),
#   'probabilities': array([0.9155742 , 0.08442575], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1993682], dtype=float32),
#   'logistic': array([0.23158763], dtype=float32),
#   'probabilities': array([0.76841235, 0.23158762], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.71491444], dtype=float32),
#   'logistic': array([0.32851383], dtype=float32),
#   'probabilities': array([0.67148614, 0.32851383], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.992818], dtype=float32),
#   'logistic': array([0.27035582], dtype=float32),
#   'probabilities': array([0.7296442 , 0.27035585], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %% [markdown]
# # DNN Classifier

# %% [markdown]
# https://www.tensorflow.org/api_docs/python/tf/estimator/DNNClassifier

# %%
# three layers of neural network
dnn_model = tf.estimator.DNNClassifier(hidden_units=[8,8],feature_columns=feat_cols,n_classes=2)

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# Items of feature_columns must be a _DenseColumn (use embedding)

# dnn_model.train(input_fn=input_func,steps=1000)

# %% [markdown]
# **Categorical Columns Must be Embedded**

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],
                                       feature_columns=feat_cols,
                                       n_classes=2,
                                       optimizer=tf.train.ProximalAdagradOptimizer(
                                       learning_rate=0.03,
                                       l1_regularization_strength=0.001)
#                                        batch_norm=False
                                       )

dnn_model.train(input_fn=input_func,steps=1000)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],
                                       feature_columns=feat_cols,
                                       n_classes=2,
                                        optimizer=tf.train.AdamOptimizer(
                                       learning_rate=0.03),
                                       dropout=0.1,
                                       activation_fn = tf.nn.relu
#                                        batch_norm=False
                                       )

dnn_model.train(input_fn=input_func,steps=1000)

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# {'accuracy': 0.6771653,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.8027393,
#  'auc_precision_recall': 0.6345963,
#  'average_loss': 0.6866669,
#  'label/mean': 0.34251967,
#  'loss': 6.708207,
#  'precision': 0.51655626,
#  'prediction/mean': 0.5488762,
#  'recall': 0.8965517,
#  'global_step': 1000}

# %% [markdown]
# # Great Job!
